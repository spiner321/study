# %%
import shutil
shutil.make_archive('training', 'zip', './kitti/training')

# %%
# 압축하기

import shutil

filename = 'testing'
archive_format = 'zip'
extract_dir = './kitti/testing'

shutil.make_archive(filename, archive_format, extract_dir)
# Out:
# '/data/kimgh/testing.zip'

# %%
# 압축해제

import shutil

filename = '/content/MarkupSafe-0.18.tar.gz'
extract_dir = './MarkupSafe'
archive_format = 'tar'

shutil.unpack_archive(filename, extract_dir, archive_format)

# %%
# %pwd
# Out:
# '/data/kimgh'
