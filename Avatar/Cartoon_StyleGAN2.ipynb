# %%
# %cd /content/drive/MyDrive/workspace/study/Avatar
# !git clone https://github.com/happy-jihye/Cartoon-StyleGAN.git
# Out:
# /content/drive/MyDrive/workspace/study/Avatar
# Cloning into 'Cartoon-StyleGAN'...
# remote: Enumerating objects: 162, done.
# remote: Counting objects: 100% (31/31), done.
# remote: Compressing objects: 100% (8/8), done.
# remote: Total 162 (delta 24), reused 23 (delta 23), pack-reused 131
# Receiving objects: 100% (162/162), 128.88 MiB | 18.07 MiB/s, done.
# Resolving deltas: 100% (42/42), done.
# Checking out files: 100% (82/82), done.
